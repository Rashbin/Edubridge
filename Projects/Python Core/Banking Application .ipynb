# %%
class CreateAccount:
    def creation(self):
        try:
            ca=" ACCOUNT CREATION "
            ca=ca.center(31,"*")
            print(ca)
            print()
            CreateAccount.name=input("Name :")
            CreateAccount.address=input("Address :")
            CreateAccount.mobile=int(input("Mobile Number:"))
            if len(str(CreateAccount.mobile))!=10:
                print("Please Enter Valid Mobile Number !!!!!!!!")
                CreateAccount.mobile=int(input("Mobile Number:"))
            CreateAccount.email=input("Email :")
            CreateAccount.password=input("Password :")
                
   
        except ValueError:
            print("\nPlease Enter valid informations\n")
        except:
            print("Something went wrong!!!!!!.....Please Re enter your details")
            CreateAccount.creation(self)
            
        else:
            print("\nHello ",CreateAccount.name,"....Your Account Creation is successfull\n")
            print("Your account number is created")
            CreateAccount.login(self)
                
    def login(self):
        ld=" LOGIN "
        ld=ld.center(31,"*")
        print(ld)
        print()
        username=input("Mobile Number :")
        paswd=input("Password :")
        if (str(CreateAccount.mobile)==str(username) and str(CreateAccount.password)==str(paswd)):
            print("\nWelcome........",CreateAccount.name,"\nYou successfully logged in\n")
        else:
            print("You Entered wrong informations")
        
    def exit(self):
        print("\nThank you....",CreateAccount.name)
        
    
        
class user:
    def __init__(self):
        self.balance=0


    def Deposit(self):
        amount=float(input("Enter the amount to be deposited:"))
        if amount>0:
            self.balance=self.balance+amount
            print("Deposit is successful and the balance in the amount is %f" % self.balance)
        else:
            print("Invalid amount transaction aborted")
            
    def Withdraw(self):
        amount=float(input("Enter the amount to be withdrawn: "))
        if self.balance>=amount and amount>0:
            self.balance=self.balance-amount
            print("The withdraw is successful and  current balance is %f" % self.balance)
        else:
            print("Insufficient balance")
            
    def Enquiry(self):
        print("Balance in the account is %f" % self.balance)
        
a=user()              
st=CreateAccount()

print("WELCOME \n")

try:
    choicelist1="yes"
    choice=input("Type Yes or No , If you are visiting this bank first time\n")
    choicelower=choice.lower()
            
    if choicelower==choicelist1:
        st.creation()
    else:
        st.login()
except ValueError:
    print("\nPlease Provide valid Informations\n")
    st.login()
except :
    print("\nYou Entered wrong username or password\n")
    st.login()
    
           
ch1="y"
while(ch1=="y"):
    print("1.Deposit \n 2.Withdraw \n 3.Check balance")
    ch=int(input("select any option"))
    if ch==1:
        a.Deposit()
    elif ch==2:
        a.Withdraw()
    elif ch==3:
        a.Enquiry()
    else:
        int(input("please  select any of the above option:"))
    print("do you want to continue, press y otherwise press n")
    ch1=input()
    if ch1=="n":
        break
if ch1=="n":
    st.exit()
# Out:
# WELCOME
#
# Type Yes or No , If you are visiting this bank first time
# yes
# ******* ACCOUNT CREATION ******
#
# Name :Rash
# Address :Kambiliparmbil
# Mobile Number:9876543211
# Email :fvgf@gmail.com
# Password :123
#
# Hello  Rash ....Your Account Creation is successfull
#
# Your account number is created
# ************ LOGIN ************
#
# Mobile Number :9876543211
# Password :123
#
# Welcome........ Rash
# You successfully logged in
#
# 1.Deposit
#  2.Withdraw
#  3.Check balance
# select any option1
# Enter the amount to be deposited:8000
# Deposit is successful and the balance in the amount is 8000.000000
# do you want to continue, press y otherwise press n
# y
# 1.Deposit
#  2.Withdraw
#  3.Check balance
# select any option2
# Enter the amount to be withdrawn: 100
# The withdraw is successful and  current balance is 7900.000000
# do you want to continue, press y otherwise press n
# y
# 1.Deposit
#  2.Withdraw
#  3.Check balance
# select any option3
# ...
